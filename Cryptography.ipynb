# %% [markdown]
# # Cryptography library

# %% [markdown]
# **Cryptography library** is one of the many libraries and modules that Python offers for secure communication and encryption.
# * Not part of python standard library

# %% [markdown]
# What is inside this Notebook:
#
#
# *   Package Installation
# *   String Text Encryption/Decryption
# *   File Encryption/Decryption
# *   Resources

# %% [markdown]
# ## 1. Installing the package

# %%
pip install cryptography
# Out:
# Requirement already satisfied: cryptography in c:\users\sumaya\anaconda3\lib\site-packages (3.4.8)
# Requirement already satisfied: cffi>=1.12 in c:\users\sumaya\anaconda3\lib\site-packages (from cryptography) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\sumaya\anaconda3\lib\site-packages (from cffi>=1.12->cryptography) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
from cryptography.fernet import Fernet #Importing the Fernet Module from the cryptography package

# %% [markdown]
# **Fernet** guarantees that a message encrypted using it cannot be manipulated or read without the key.
#
# The fernet module of the library provides a** built-in key generator** and provides **encryption and decryption functions** for a string of data and large files.
#
# Fernet is an implementation of symmetric (also known as “secret key”) authenticated cryptography.

# %% [markdown]
# ## 2. String Text Encryption/Decryption

# %%
secret_message = input("please Enter the meassage you want to encrypt: ")
# Out:
# please Enter the meassage you want to encrypt: I dont like presentaions!! lol

# %%
type(secret_message)
# Out:
# str

# %%
secret_message_in_byte = secret_message.encode() #Message needs to be converted to BYTE format for encryption functions

# %%
type(secret_message_in_byte) #Byte is a machine readable formates (Sequence of Bytes), 
#String is human readable, sequence of chars
# Out:
# bytes

# %% [markdown]
# ![title](img/picture.png)

# %% [markdown]
# ### 2.1 Key Generation

# %%
key = Fernet.generate_key() #Generating Key, should be run once as everytime it runs, different key gets generated 
key #Encoded_base64 32Byte
# Out:
# b'B1sKmKv8wVapD62n4Hz48Q7Oz03frC2cLPYZmU6bz6M='

# %% [markdown]
# ### 2.2 Message Encryption

# %%
f = Fernet(key) #instintiate a Fernet object and passing the ke

# %%
encrypted_message = f.encrypt(secret_message_in_byte) #used the encrypt function of the fernet object we createdd

# %%
encrypted_message #encrypted message
# Out:
# b'gAAAAABjPKd2NIX0NmrQBcFZM82ZKZ8Nz_Aaeh-akNdN1vpyu5mltRNazyL24OJ4PU-_bt_eQ0tKhS1zqevrgGwFQSp0I5Vzwj4c3r9XzyqhlxFDvBnY47s='

# %%
type(encrypted_message) #type of the encrypted_message
# Out:
# bytes

# %% [markdown]
# ### 2.3 Message Decryption

# %%
#Use the decryption method from the same fernet object we instantiated using the key
decrepted_message = f.decrypt(encrypted_message)

# %%
decrepted_message
# Out:
# b'I dont like presentaions!! lol'

# %%
string_message = decrepted_message.decode() #decode message to get it back in str

# %%
type(string_message)
string_message
# Out:
# 'I dont like presentaions!! lol'

# %% [markdown]
# ## 3. File Encryption:

# %%
import pandas as pd 
df = pd.read_excel('Users_Information_File.xlsx')

# %%
df.head(10)
# Out:
#   first_name last_name                address         city          county  \
# 0      James      Butt     6649 N Blue Gum St  New Orleans         Orleans
# 1  Josephine   Darakjy    4 B Blue Ridge Blvd     Brighton      Livingston
# 2        Art    Venere   8 W Cerritos Ave #54   Bridgeport      Gloucester
# 3      Lenna  Paprocki            639 Main St    Anchorage       Anchorage
# 4    Donette    Foller           34 Center St     Hamilton          Butler
# 5     Simona   Morasca           3 Mcauley Dr      Ashland         Ashland
# 6     Mitsue   Tollner              7 Eads St      Chicago            Cook
# 7      Leota  Dilliard       7 W Jackson Blvd     San Jose     Santa Clara
# 8       Sage    Wieser       5 Boston Ave #88  Sioux Falls       Minnehaha
# 9       Kris   Marrier  228 Runamuck Pl #2808    Baltimore  Baltimore City
#
#   state    zip        phone1                          email        SSN
# 0    LA  70116  504-621-8927                jbutt@gmail.com  635775266
# 1    MI  48116  810-292-9388  josephine_darakjy@darakjy.org  659901739
# 2    NJ   8014  856-636-8749                 art@venere.org  972100824
# 3    AK  99501  907-385-4412          lpaprocki@hotmail.com  826633004
# 4    OH  45011  513-570-1893         donette.foller@cox.net  844036704
# 5    OH  44805  419-503-2484             simona@morasca.com  669023219
# 6    IL  60632  773-573-6914       mitsue_tollner@yahoo.com  366072507
# 7    CA  95111  408-752-3500              leota@hotmail.com  238873235
# 8    SD  57105  605-414-2147            sage_wieser@cox.net  224592257
# 9    MD  21224  410-655-8723                 kris@gmail.com  390861202

# %% [markdown]
# ### 3.1 Key Generation

# %%
key = Fernet.generate_key()

#Write key to a file and save it in secure place , run this once 
with open('keyfile.key', 'wb') as keyfile:
    keyfile.write(key)

# %%
#Each time you want to access the key you can do so using below code:
with open('keyfile.key', 'rb') as keyfile:
    key= keyfile.read()

# %%
f= Fernet(key) #instantiate a fernet object

# %% [markdown]
# ### 3.2 Reading Data from file in Byte

# %%
with open('Users_Information_File.xlsx', 'rb') as myFile:
  data = myFile.read()

# %%
print(data)
# Out:
# b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00\x9e,lok\x01\x00\x00\x10\x05\x00\x00\x13\x00\x08\x02[Content_Types].xml \xa2\x04\x02(N\xc30\x0c\x86\xefH\xbcC\x95+j\xb3q@\x08\xad\xdba\xc0\x11&1\x1e $\xee\x1a-M\xa28\x1b\xdb\xdb\xe3fcB\xa8\xacB\xeb\xa5Q\x1b\xfb\xff\xbf\xb8v&\xb3]c\xb2-\x04\xd4\xce\x96l\\\x8cX\x06V:\xa5\xed\xaad\xef\xcb\xe7\xfc\x9ee\x18\x85U\xc28\x0b%\xdb\x03\xb2\xd9\xf4\xfaj\xb2\xdc{\xc0\x8c\xb2-\x96\xac\x8e\xd1?p\x8e\xb2\x86F`\xe1<X\xda\xa9\\hD\xa4\xd7\xb0\xe2^\xc8\xb5X\x01\xbf\x1d\x8d\xee\xb8t6\x82\x8dyl5\xd8t\xf2\x08\x95\xd8\x98\x98=\xed\xe8\xf3\x81$\x80A\x96\xcd\x0f\x81\xadW\xc9\x84\xf7FK\x11\x89\x94o\xad\xfa\xe5\x92\x1f\x1d\n\xcaL1Xk\x8f7\x84\xc1x\xa7C\xbb\xf3\xb7\xc11\xef\x95J\x13\xb4\x82l!B|\x11\ra\xf0\x9d\xe1\x9f.\xac?\x
QXnqGPLICvT0YCSyGFGS4SPTV1VstRYJM7scG9xRZ9gFNmT5Qi0X-nU04Ao9Exkj1kzb8J-mk--fpEMYQEpPCOBThNdIFni8Lr7_Nk8U59ppxziuHTEo42BSdYJUA4eUYhbrT_viY8DzgYobliGkvMh9gRl76uilr8L8ScETVW3PFXaoePAtCr1Sl0MzNvHJ0FxqLXW55na3Gd6Sg7Y-cEQjRE8t4wU75NclWv8UOMAD6e2ffJwNr0LtsAGRUaL4imHnM1Rx2yGaxt6xYnZoxac6xNUYO4AkHCYnxi4My_008tgTYQLHclVaTVJnycMPjE2tHFBItLLiwQ3_0s6bR-kmBcVhPi3O7ly-UCeZC9vcIsCRsted_sN7J4X5LLzCj6SsA-ENM9gWyQsU_dx-0b3NZ7lsm4JNY8DeXgb9RDTwpg6r9-ANY9Pj1bHVGAVcKLvA5eNVQOqD1S_xXyCRetrMu-QBFzMiOvwaZmVwSPo5gy7qccf8a50e01z7d-nvb9s1P3A91lrK-30WfUM0DHhbq6Hrq2StS22Dw-x3zxWyxo9c0FgcBH5Dh6ZqaTmlxGrRJeNHnwo2BQ3Mb-lhU8u-a3Do-cF86S4-Cb-DApx-m3HhBKoFbW4vIJs1CoPbmFHJAcJhBsuvv9YqQ6yjukISO5oHDnw9qx97l9DTp_urz4hr1kr0cU2steQaRLro1lb4TiVXeTdXS2I_YaCZzmZrGBtUWVkMn3Y0PIsXGcBYEoiypdfFxKaeqZmM0tNCzBkpEfS5EivGYRVzUD9iqeLboIn82Eulzq2MPFqtl6GRPc3B7_bs2TYX7ApGDta2k9lyjcOdunETGhML7V576ldOCUZkeJuEHujyqSPfg-_216vyhbZSFTzaEclxDqbQEYwckRLZ-dmiaIlYeGgE_032I-XlABN97ck2sa6UI1OvlddHlQ8Wj5ZgfCWytIaTk2_W_gd_rUHpvgkwIfYp3DT44yWD9AWKp3xpfsbMiQHKr3oPzcO19hwEttJ1yvDKBV7_BtzMWwQXxi0BhYFhEyHc530Ypar22egl3RuhlcSpb-74Olxr5XY7ePBmJ3QTeHXnx4u-et6l9PPmN-g_8PYLSLrq9QvOG7vyAgMnLpuN70fv1SDKdBFeAJF_ORpJUJe5hf3-SMt9CXpbHMCKcyD_o1VduVU6s6F-0pcWWA-kl9Xqo4KVU9X9O0shCBqc8k6cZ2vYS-O-aYUnRAL2zVX92YKOUuEZfj3ACjBz9P4WBkcEXww7TaRVeM7CxniffwCWqhGNG3jWE4GXwjeWBJr2MytC0mDCSvSbH23gIJbkDU3KoLmzFM-5VJGyAukH7d_v1sGTt7vFeMD6mO5xWtrFSMFHChHHvlI0fbDt0p4syM ...

# %%
#Saving Encrypted Data into a file in Byte formate
with open('Users_Information_encrypted', 'wb') as myFile:
     myFile.write(encrypted_data)

# %% [markdown]
# ### 3.4 Accessing data and decryption:

# %%
#read the file using 
with open('Users_Information_encrypted', 'rb') as myFile:
     encrypted_message = myFile.read()

# %%
#Get the Key
with open('keyfile.key', 'rb') as keyfile:
    key= keyfile.read()

# %%
#instintiate an object from Fernet class 
fernet = Fernet( key)

# %%
decrypted_message = fernet.decrypt(encrypted_data)

# %%
decrypted_message
# Out:
# b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00\x9e,lok\x01\x00\x00\x10\x05\x00\x00\x13\x00\x08\x02[Content_Types].xml \xa2\x04\x02(N\xc30\x0c\x86\xefH\xbcC\x95+j\xb3q@\x08\xad\xdba\xc0\x11&1\x1e $\xee\x1a-M\xa28\x1b\xdb\xdb\xe3fcB\xa8\xacB\xeb\xa5Q\x1b\xfb\xff\xbf\xb8v&\xb3]c\xb2-\x04\xd4\xce\x96l\\\x8cX\x06V:\xa5\xed\xaad\xef\xcb\xe7\xfc\x9ee\x18\x85U\xc28\x0b%\xdb\x03\xb2\xd9\xf4\xfaj\xb2\xdc{\xc0\x8c\xb2-\x96\xac\x8e\xd1?p\x8e\xb2\x86F`\xe1<X\xda\xa9\\hD\xa4\xd7\xb0\xe2^\xc8\xb5X\x01\xbf\x1d\x8d\xee\xb8t6\x82\x8dyl5\xd8t\xf2\x08\x95\xd8\x98\x98=\xed\xe8\xf3\x81$\x80A\x96\xcd\x0f\x81\xadW\xc9\x84\xf7FK\x11\x89\x94o\xad\xfa\xe5\x92\x1f\x1d\n\xcaL1Xk\x8f7\x84\xc1x\xa7C\xbb\xf3\xb7\xc11\xef\x95J\x13\xb4\x82l!B|\x11\ra\xf0\x9d\xe1\x9f.\xac?\x9c[\x17\xe7E:(]Ui\t\xca\xc9MC\x15(\xd0\x07\x10\nk\x80\xd8\x98"\xadE#\xb4\xfd\xe6>\xe3\x9f\x82\x91\xa7e<0H{\xbe$\xdc\xc3\x11\xe9\x7f\x03O\xcf\xcb\x11\x92L\x8f!\xc6\xbd\x01\x1c\xba\xecI\xb4\xcf\xb9\x16\x01\xd4[\x0c4\x19\x83\x03\xfc\xd4\xee\xe1\x90\xc2\xc8yM-2p\x11N\xba\xe7\xfc\xa9o\x17\xc1y\xa4\t\x0e\xf0\x7f\x80\xef\x11m\xb3sOB\x10\xa2\x86\xd3\x90v5\xfb\xc9\x91\xa6\xff\xe2\x13C{\xbf(P\x1d\xde<\xddg\xd3/\x00\x00\x00\xff\xff\x03\x00PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00\xb5U0#\xf4\x00\x00\x00L\x02\x00\x00\x0b\x00\x08\x02_rels/.rels \xa2\x04\x02(\x0 ...

# %%
#Write the decrypted data to a file
with open('Users_Information_updated_After_decryption.xlsx', 'wb') as myFile:
     myFile.write(decrypted_message)

# %% [markdown]
# # 5. Resources

# %% [markdown]
# *   Documentaion: https://cryptography.io/en/latest/fernet/
# *   Tutorial: https://linuxhint.com/cryptography-with-python/
# *   Symmertic Encryption: https://www.geeksforgeeks.org/fernet-symmetric-encryption-using-cryptography-module-in-python/
# *   Crytographyy Project: https://pypi.org/project/cryptography/
# *   Bytes and String: https://www.geeksforgeeks.org/byte-objects-vs-string-python/
